# %%
from eigen_tech_project.inverted_index import InvertedIndex

# %%
ii = InvertedIndex("data/")

# %%
ii.processed_sentences
# Out:
# [(6, ' Good morning.', ''),
#  (6,
#   "As some of you know, Senator Lugar and I recently traveled to Russia, Ukraine, and Azerbaijan to witness firsthand both the progress we're making in securing the world's most dangerous weapons, as well as the serious challenges that lie ahead.",
#   'senator lugar recently russia ukraine azerbaijan witness firsthand progress secure dangerous weapon serious challenge ahead'),
#  (6,
#   'Now, few people understand these challenges better than the co-founder of the Cooperative Threat Reduction Program, Dick Lugar, and this is something that became particularly clear to me during one incident on the trip.',
#   'understand challenge co founder cooperative threat reduction program dick lugar something become particularly incident'),
#  (6,
#   'We were in Ukraine, visiting a pathogen laboratory in Kiev.',
#   'ukraine pathogen laboratory kiev'),
#  (6,
# ...

# %%
import contextlib

# %%
ii.mapped_inverted_index
# Out:
#            lemma  frequency  \
# 0       american         73
# 1           iraq         64
# 2        america         54
# 3     government         47
# 4        promise         40
# ...          ...        ...
# 1958  importance          1
# 1959      import          1
# 1960   imperfect          1
# 1961      impact          1
# 1962        zone          1
#
#                                               sentences           documents
# 0     [But, when I think about what is at stake I am...  {1, 2, 3, 4, 5, 6}
# 1     [A few Tuesdays ago, the American people embra...        {1, 2, 3, 5}
# 2     [A few Tuesdays ago, the American people embra...     {1, 2, 3, 4, 5}
# 3     [And the Kiev story is heading in the right di...  {1, 2, 3, 4, 5, 6}
# 4     [One statistic powerfully describes this unful...        {1, 2, 3, 4}
# ...                                                 ...                 ...
# 1958  [It is simply not productive for us not to eng...                 {5}
# ...

# %%
dir(ii.lemma_frequencies)
# Out:
# ['A',
#  'A1',
#  'H',
#  'I',
#  'T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_finalize__',
#  '__array_function__',
#  '__array_interface__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_struct__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__complex__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__ilshift__',
#  '__imatmul__',
#  '__imod__',
#  '__imul__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lshift__',
# ...

# %%
lemma_occurences = ii.lemma_occurrences

# %%
document_term_matrix.shape[1]
# Out:
# 1963

# %%
x = document_term_matrix.shape[1]

occurences = [document_term_matrix[:, i].nonzero()[0].tolist() for i in range(0, x)]

# %%
document_term_matrix.transpose().tolil().rows
# Out:
# array([list([133, 134, 135, 428, 772]), list([575, 699]),
#        list([97, 274, 607, 622, 838, 839]), ..., list([139]), list([53]),
#        list([201])], dtype=object)

# %%
if document_term_matrix.transpose().tolil().rows.tolist() == occurences:
    print("check")
# Out:
# check

# %%
occurences
# Out:
# [[133, 134, 135, 428, 772],
#  [575, 699],
#  [97, 274, 607, 622, 838, 839],
#  [428],
#  [812],
#  [575],
#  [314],
#  [84, 89],
#  [39],
#  [290],
#  [25],
#  [25],
#  [220],
#  [325],
#  [630],
#  [25],
#  [118, 371],
#  [79, 128, 182],
#  [183],
#  [519],
#  [406, 708, 732, 858],
#  [772],
#  [134],
#  [133],
#  [273],
#  [623],
#  [877],
#  [735],
#  [613, 772, 773],
#  [353],
#  [841],
#  [110],
#  [801],
#  [247],
#  [882],
#  [72, 226, 340, 394],
#  [876],
#  [457],
#  [836],
#  [214, 468],
#  [149],
#  [64, 221, 370, 395],
#  [17, 27],
#  [281, 429, 485, 711],
#  [106, 143],
#  [51, 331, 386, 475, 677],
#  [668, 821],
#  [712],
#  [107, 342],
#  [132, 165, 273],
#  [386, 491, 819],
#  [340, 392, 404, 907],
#  [398],
#  [48, 148, 158, 163, 164, 716],
#  [485],
#  [312],
#  [47, 55, 340, 492, 684, 699, 731, 894, 907],
#  [140, 261],
#  [207, 435],
#  [364],
#  [685, 756, 839],
#  [485],
#  [804, 807],
#  [135, 385],
#  [52, 195],
#  [64],
#  [72, 213],
#  [216],
#  [192],
# ...

# %%
# %%time

x = ii.inverted_index

# %%
# %%time

solution = ii.solution

# %%
from nltk.corpus import wordnet

# %%
treebank_tags = ["CC", "CD", "DT", "EX", "FW", "IN", "JJ", "JJR", "JJS", "LS", "MD", "NN", "NNS", "NNP",
                 "NNPS", "PDT", "POS", "PRP", "PRP$", "RB", "RBR", "RBS", "RP", "SYM", "TO", "UH", "VB",
                 "VBD", "VBG", "VBN", "VBP", "VBZ", "WDT", "WP", "WP$", "WRB"]

# %%
from eigen_tech_project.nlp_processing import Lemmatizer

lemmatizer = Lemmatizer()

x = []

for tag in treebank_tags:
    x.append(lemmatizer.get_wordnet_pos(tag))

# %%
x

# %%
solution.lemma

# %%
len(x)

# %%
set([1,2,3] + [4,5,6])

# %%
import nltk
nltk.corpus.stopwords.words("english")
